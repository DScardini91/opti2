# %% [markdown]
# # Warehouse Problem - Lagrangian relaxation
#
# Let us recall the original MIP formulation:
#
# \begin{align*}
# \min &\qquad \sum_w c_w x_w + \sum_{w ,c} t_{w,c} y_{w,c}  & \\
# \text{subject to:} &&\\
# &y_{w,c} \leq x_w & \forall w,c \\
# &\sum_w y_{w,c} = 1 & \forall c \\
# &\sum_c y_{w,c} \leq C_w  x_w & \forall w \\
# &x_w, y_{w,c}, z_c \in \mathbb{B} & \forall w,c
# \end{align*}

# %% [markdown]
# $\mathcal{L}(x,y,\lambda) = \sum_w c_wx_w + \sum_{w,c} t_{w,c}y_{w,c} + \sum_c \lambda_c (1 - \sum_w y_{w,c})$

# %%
fixed = 30  # c_w (all the costs are the same)
M = 10*fixed  # the penalty
capacity = [1,4,2,1,3]  # the capacity of a warehouse
supplyCost = [[20,24,11,25,30],  # t_{w,c}
              [28,27,82,83,74],
              [74,97,71,96,70],
              [2,55,73,69,61],
              [46,96,59,83,4],
              [42,22,29,67,59],
              [1,5,73,59,56],
              [10,73,13,43,96],
              [93,35,63,85,46],
              [47,65,55,71,95]]
nbStores = len(supplyCost)
nbWarehouses = len(capacity)
Stores = range(nbStores)
Warehouses = range(nbWarehouses)

# %% [markdown]
# ### Excercices
#
# #### 1. Find the lagrangian relaxation formulation where the constraints 2 are relaxed.
#
# #### 2. Implement the lagrangian relaxation.

# %%
from docplex.mp.model import Model

def lagrangian_relaxation(rlambda=[1]*nbStores):
    model = Model(name='lagrangian')
    
     # Decision variables
    x = {w: model.binary_var(name=f'x_{w}') for w in Warehouses}  # 1 if warehouse w is open
    y = {(w, s): model.binary_var(name=f'y_{w}_{s}') for w in Warehouses for s in Stores}  # 1 if customer s is served by warehouse w
    
    # Lagrangian objective function
    Lagrangian_obj = sum(fixed * x[w] for w in Warehouses) + \
                     sum(supplyCost[s][w] * y[w, s] for w in Warehouses for s in Stores) + \
                     sum(rlambda[s] * (1 - sum(y[w, s] for w in Warehouses)) for s in Stores)

    # Constraints: if a warehouse is not open, it cannot supply any store
    for w in range(nbWarehouses):
        for s in range(nbStores):
            model.add_constraint(y[w, s] <= x[w], f'supply_{s}_{w}')  # If warehouse w is closed, it cannot serve any store

    # Constraints: each warehouse cannot serve more stores than its capacity
    for w in range(nbWarehouses):
        model.add_constraint(model.sum(y[w, s] for s in range(nbStores)) <= capacity[w] * x[w], f'capacity_{w}')  # Respect warehouse capacity

    
    # Set the objective
    model.minimize(Lagrangian_obj)

    # Solve the model
    solution = model.solve()
    
    # Print the solution
    if solution:
        print(f"Lagrangian Objective Value: {solution.objective_value.}")
      
    else:
        print("No feasible solution found for the Lagrangian Objective function.")
    
    relaxation_constraints = [1 - sum(y[w, s].solution_value for w in Warehouses) for s in Stores]
    
    x_sol = [x[w].solution_value for w in Warehouses]
    y_sol = {(w, s): y[w,s].solution_value for w in Warehouses for s in Stores}
    
    return (model.objective_value,  # the objective value
            solution, # solution
            relaxation_constraints,
            x_sol,
           y_sol)  # slack of the relaxed constraints
# Out:
#   Cell In[27], line 33
#     print(f"Lagrangian Objective Value: {solution.objective_value.2f}")
#                      ^
# SyntaxError: f-string: invalid syntax

# %% [markdown]
# #### 3. Implement the Cutting Plane Method
#
# 1. State the master problem
# 2. Keep track of the best feasible solution
# 3. Use the solution to the master problem to solve the Lagrangian subproblem

# %%
rlambda = [fixed]*nbStores
fsol = None
iteration = 0
step = 1
UB = M*nbStores
bestFeasibleValue = UB
bestFeasible = 0


mdl = Model(name='lagrangian')
u = mdl.continuous_var_list(nbStores, name='lambda', ub=M)
v = mdl.continuous_var(name='lagrangian_dual')
mdl.maximize(v)
iteration = 0 

while True:

    print("-"*40)
    print(f"Iteration # {iteration+1}")
    sub_obj, msol, relaxation_constraints, x_sol, y_sol = lagrangian_relaxation(rlambda)
    
    mdl.add_constraint(v <= (sum(fixed * x_sol[w] for w in Warehouses) + \
                             sum(supplyCost[s][w] * y_sol[w, s] for w in Warehouses for s in Stores)) + \
                               sum(u[s]*relaxation_constraints[s] for s in Stores)
                      )

    solution = mdl.solve()

    rlambda = [u[s].solution_value for s in Stores]

    master_obj = solution.objective_value

    

    iteration += 1
    print(f"Duality gap = {master_obj - obj}\n")
    print(f"Master Objective Value {master_obj}")

    tolerance = 10e-5
    # Check if all relaxation constraints are satisfied
    if abs(master_obj - sub_obj) <= tolerance:
        break
        
  
print('========================')
print('Lagrangian dual: ' + str(UB))
if bestFeasible != 0:
    print('-- best feasible --')
    print(bestFeasible)
# Out:
# ----------------------------------------
# Iteration # 1
# Lagrangian Objective Value: 282.0
# Duality gap = 1380.0
#
# Master Objective Value 1662.0
# ----------------------------------------
# Iteration # 2
# Lagrangian Objective Value: -1103.0
# Duality gap = 958.3333333333333
#
# Master Objective Value 1240.3333333333333
# ----------------------------------------
# Iteration # 3
# Lagrangian Objective Value: -535.6666666666665
# Duality gap = 662.3333333333333
#
# Master Objective Value 944.3333333333333
# ----------------------------------------
# Iteration # 4
# Lagrangian Objective Value: -787.6666666666667
# Duality gap = 581.0
#
# Master Objective Value 863.0
# ----------------------------------------
# Iteration # 5
# Lagrangian Objective Value: -1111.3333333333333
# Duality gap = 445.625
#
# Master Objective Value 727.625
# ----------------------------------------
# Iteration # 6
# Lagrangian Objective Value: -1052.125
# Duality gap = 361.3571428571429
#
# Master Objective Value 643.3571428571429
# ----------------------------------------
# Iteration # 7
# Lagrangian Objective Value: -994.047619047619
# Duality gap = 309.7335640138409
#
# Master Objective Value 591.7335640138409
# ----------------------------------------
# Iteration # 8
# Lagrangian Objective Value: -910.2733564013836
# Duality gap = 284.1729241877257
#
# Master Objective Value 566.1729241877257
# ----------------------------------------
# Iteration # 9
# Lagrangian Objective Value: -224.67400722021665
# Duality gap = 276.4245257155392
#
# Master Objective Value 558.4245257155392
# ----------------------------------------
# Iteration # 10
# Lagrangian Objective Value: 35.49923237197157
# Duality gap = 274.5934722957685
#
# Master Objective Value 556.5934722957685
# ----------------------------------------
# Iteration # 11
# Lagrangian Objective Value: 153.8070427959371
# Duality gap = 270.5961144842262
#
# Master Objective Value 552.5961144842262
# ----------------------------------------
# Iteration # 12
# Lagrangian Objective Value: 360.84995148973434
# Duality gap = 255.9962607012826
#
# Master Objective Value 537.9962607012826
# ----------------------------------------
# Iteration # 13
# Lagrangian Objective Value: -258.9383343720299
# Duality gap = 248.91094591263493
#
# Master Objective Value 530.9109459126349
# ----------------------------------------
# Iteration # 14
# Lagrangian Objective Value: 259.61898312121383
# Duality gap = 219.19119036372217
#
# Master Objective Value 501.19119036372217
# ----------------------------------------
# Iteration # 15
# Lagrangian Objective Value: 157.061761927255
# Duality gap = 203.14327122153202
#
# Master Objective Value 485.143271221532
# ----------------------------------------
# Iteration # 16
# Lagrangian Objective Value: 268.45952380952474
# Duality gap = 200.6050792332711
#
# Master Objective Value 482.6050792332711
# ----------------------------------------
# Iteration # 17
# Lagrangian Objective Value: -31.6845893017786
# Duality gap = 200.30998445369698
#
# Master Objective Value 482.309984453697
# ----------------------------------------
# Iteration # 18
# Lagrangian Objective Value: 325.00570112845554
# Duality gap = 190.32744506678148
#
# Master Objective Value 472.3274450667815
# ----------------------------------------
# Iteration # 19
# Lagrangian Objective Value: 263.56484274019823
# Duality gap = 188.02877753645686
#
# Master Objective Value 470.02877753645686
# ----------------------------------------
# Iteration # 20
# Lagrangian Objective Value: 223.2760626745264
# Duality gap = 180.80997343664825
#
# Master Objective Value 462.80997343664825
# ----------------------------------------
# Iteration # 21
# Lagrangian Objective Value: 299.68724263127984
# Duality gap = 180.32007972188353
#
# Master Objective Value 462.32007972188353
# ----------------------------------------
# Iteration # 22
# Lagrangian Objective Value: 326.51237691341606
# Duality gap = 168.24311456946873
#
# Master Objective Value 450.24311456946873
# ----------------------------------------
# Iteration # 23
# Lagrangian Objective Value: 364.2874475273884
# Duality gap = 161.77202842377267
#
# Master Objective Value 443.77202842377267
# ----------------------------------------
# Iteration # 24
# Lagrangian Objective Value: 292.90490956072335
# Duality gap = 155.88955823293173
#
# Master Objective Value 437.88955823293173
# ----------------------------------------
# Iteration # 25
# Lagrangian Objective Value: 362.14196787148614
# Duality gap = 149.3992673992675
#
# Master Objective Value 431.3992673992675
# ----------------------------------------
# Iteration # 26
# Lagrangian Objective Value: 314.98168498168496
# Duality gap = 144.02813436029095
#
# Master Objective Value 426.02813436029095
# ----------------------------------------
# Iteration # 27
# Lagrangian Objective Value: 251.21544715447186
# Duality gap = 142.34355828220856
#
# Master Objective Value 424.34355828220856
# ----------------------------------------
# Iteration # 28
# Lagrangian Objective Value: 314.68098159509276
# Duality gap = 139.75905673274087
#
# Master Objective Value 421.7590567327409
# ----------------------------------------
# Iteration # 29
# Lagrangian Objective Value: 309.22043745727916
# Duality gap = 138.91607082056527
#
# Master Objective Value 420.91607082056527
# ----------------------------------------
# Iteration # 30
# Lagrangian Objective Value: 353.88193735103863
# Duality gap = 136.0463768115941
#
# Master Objective Value 418.0463768115941
# ----------------------------------------
# Iteration # 31
# Lagrangian Objective Value: 332.80048309178727
# Duality gap = 135.62705882352947
#
# Master Objective Value 417.62705882352947
# ----------------------------------------
# Iteration # 32
# Lagrangian Objective Value: 294.9176470588231
# Duality gap = 135.2182802164764
#
# Master Objective Value 417.2182802164764
# ----------------------------------------
# Iteration # 33
# Lagrangian Objective Value: 343.6624574062943
# Duality gap = 135.2182802164764
#
# Master Objective Value 417.2182802164764
# ----------------------------------------
# Iteration # 34
# Lagrangian Objective Value: 349.34816596512303
# Duality gap = 133.03338632750393
#
# Master Objective Value 415.03338632750393
# ----------------------------------------
# Iteration # 35
# Lagrangian Objective Value: 348.27186009538957
# Duality gap = 132.9078947368422
#
# Master Objective Value 414.9078947368422
# ----------------------------------------
# Iteration # 36
# Lagrangian Objective Value: 355.4122807017535
# Duality gap = 132.66439290586618
#
# Master Objective Value 414.6643929058662
# ----------------------------------------
# Iteration # 37
# Lagrangian Objective Value: 369.7114597544345
# Duality gap = 131.85327635327633
#
# Master Objective Value 413.8532763532763
# ----------------------------------------
# Iteration # 38
# Lagrangian Objective Value: 378.78490028490035
# Duality gap = 125.6246458923514
#
# Master Objective Value 407.6246458923514
# ----------------------------------------
# Iteration # 39
# Lagrangian Objective Value: 340.1605288007556
# Duality gap = 125.59644670050767
#
# Master Objective Value 407.59644670050767
# ----------------------------------------
# Iteration # 40
# Lagrangian Objective Value: 353.8654822335028
# Duality gap = 122.82618510158011
#
# Master Objective Value 404.8261851015801
# ----------------------------------------
# Iteration # 41
# Lagrangian Objective Value: 345.1422121896162
# Duality gap = 120.32
#
# Master Objective Value 402.32
# ----------------------------------------
# Iteration # 42
# Lagrangian Objective Value: 331.6266666666668
# Duality gap = 120.13432835820902
#
# Master Objective Value 402.134328358209
# ----------------------------------------
# Iteration # 43
# Lagrangian Objective Value: 343.3582089552249
# Duality gap = 118.627659574468
#
# Master Objective Value 400.627659574468
# ----------------------------------------
# Iteration # 44
# Lagrangian Objective Value: 361.8829787234042
# Duality gap = 110.25
#
# Master Objective Value 392.25
# ----------------------------------------
# Iteration # 45
# Lagrangian Objective Value: 324.1250000000001
# Duality gap = 110.25
#
# Master Objective Value 392.25
# ----------------------------------------
# Iteration # 46
# Lagrangian Objective Value: 326.2499999999998
# Duality gap = 108.18749999999989
#
# Master Objective Value 390.1874999999999
# ----------------------------------------
# Iteration # 47
# Lagrangian Objective Value: 361.7187499999997
# Duality gap = 108.18749999999989
#
# Master Objective Value 390.1874999999999
# ----------------------------------------
# Iteration # 48
# Lagrangian Objective Value: 365.9374999999999
# Duality gap = 108.18749999999989
#
# Master Objective Value 390.1874999999999
# ----------------------------------------
# Iteration # 49
# Lagrangian Objective Value: 366.81249999999983
# Duality gap = 108.18749999999989
#
# Master Objective Value 390.1874999999999
# ----------------------------------------
# Iteration # 50
# Lagrangian Objective Value: 368.28125
# Duality gap = 108.18749999999994
#
# Master Objective Value 390.18749999999994
# ----------------------------------------
# Iteration # 51
# Lagrangian Objective Value: 369.5624999999997
# Duality gap = 108.18749999999994
#
# Master Objective Value 390.18749999999994
# ----------------------------------------
# Iteration # 52
# Lagrangian Objective Value: 369.5624999999997
# Duality gap = 108.1875
#
# Master Objective Value 390.1875
# ----------------------------------------
# Iteration # 53
# Lagrangian Objective Value: 357.1041666666666
# Duality gap = 108.1875
#
# Master Objective Value 390.1875
# ----------------------------------------
# Iteration # 54
# Lagrangian Objective Value: 370.4375
# Duality gap = 108.1875
#
# Master Objective Value 390.1875
# ----------------------------------------
# Iteration # 55
# Lagrangian Objective Value: 366.37499999999994
# Duality gap = 108.1875
#
# Master Objective Value 390.1875
# ----------------------------------------
# Iteration # 56
# Lagrangian Objective Value: 360.4374999999999
# Duality gap = 108.1875
#
# Master Objective Value 390.1875
# ----------------------------------------
# Iteration # 57
# Lagrangian Objective Value: 370.4374999999999
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 58
# Lagrangian Objective Value: 366.77499999999986
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 59
# Lagrangian Objective Value: 362.7499999999999
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 60
# Lagrangian Objective Value: 370.6249999999999
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 61
# Lagrangian Objective Value: 370.75
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 62
# Lagrangian Objective Value: 378.17499999999984
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 63
# Lagrangian Objective Value: 380.2045454545454
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 64
# Lagrangian Objective Value: 381.27272727272725
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 65
# Lagrangian Objective Value: 379.00000000000006
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 66
# Lagrangian Objective Value: 379.37499999999994
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 67
# Lagrangian Objective Value: 381.66666666666663
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 68
# Lagrangian Objective Value: 380.0
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 69
# Lagrangian Objective Value: 382.4999999999999
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 70
# Lagrangian Objective Value: 381.0
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 71
# Lagrangian Objective Value: 382.5
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 72
# Lagrangian Objective Value: 382.5
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 73
# Lagrangian Objective Value: 382.49999999999994
# Duality gap = 103.25
#
# Master Objective Value 385.25
# ----------------------------------------
# Iteration # 74
# Lagrangian Objective Value: 382.4999999999999
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 75
# Lagrangian Objective Value: 379.3333333333335
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 76
# Lagrangian Objective Value: 382.3333333333333
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 77
# Lagrangian Objective Value: 382.3333333333333
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 78
# Lagrangian Objective Value: 382.3333333333329
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 79
# Lagrangian Objective Value: 382.6666666666665
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 80
# Lagrangian Objective Value: 382.6666666666664
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 81
# Lagrangian Objective Value: 382.9999999999999
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 82
# Lagrangian Objective Value: 381.6666666666667
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 83
# Lagrangian Objective Value: 383.0
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 84
# Lagrangian Objective Value: 381.6666666666667
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 85
# Lagrangian Objective Value: 382.99999999999983
# Duality gap = 102.33333333333331
#
# Master Objective Value 384.3333333333333
# ----------------------------------------
# Iteration # 86
# Lagrangian Objective Value: 383.0
# Duality gap = 101.0
#
# Master Objective Value 383.0
# ========================
# Lagrangian dual: 3000
